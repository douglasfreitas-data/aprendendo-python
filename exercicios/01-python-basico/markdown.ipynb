# %% [markdown]
# # Texto primário
#
# ## Texto secundário
#
# ### Texto terciário

# %% [markdown]
# Corpo do texto . *Texto itálico*. **Texto em negrito**

# %% [markdown]
# - primeiro item
# - segundo item

# %% [markdown]
# 1. item
# 2. item
# 3. item

# %% [markdown]
# Abaixo será feita a operação `2 + 2`:

# %%
2 + 2
# Out:
# 4

# %% [markdown]
# https://www.google.com
#
# [Google](https://www.google.com)
