# %% [markdown]
# ## Trabalhando com texto - strings

# %%
'Isto é um Texto'
# Out:
# 'Isto é um Texto'

# %%
"Isto é um texto"
# Out:
# 'Isto é um texto'

# %%
"Caixa d'agua" #apas duplas quando houver aspas simples dentro da sentença
# Out:
# "Caixa d'agua"

# %%
print("Isto é um texto") #imprimi na tela
# Out:
# Isto é um texto

# %%
#Apas triplas para quebra de linhas

print("""
Este texto
tem mútiplas
linhas
""")

#sem print aparece \n

"""
Este texto
tem múltiplas
linhas
"""

#Tabulação

print("Olha essa \t tabulação")
# Out:
# Este texto
# tem mútiplas
# linhas
#
# Olha essa 	 tabulação
