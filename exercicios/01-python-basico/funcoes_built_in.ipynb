# %% [markdown]
# # Funções built-in - padrões

# %%
type(print)
# Out:
# builtin_function_or_method

# %%
help(print) #Ajuda sobre a função
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %%
salario = 1500
comissao = 0.05

# %%
print("Salario", salario, "Comissão", comissao)
# Out:
# Salario 1500 Comissão 0.05

# %%
print("Salario", salario, "Comissão", comissao, sep="\t")
# Out:
# Salario	1500	Comissão	0.05

# %%
help(abs)
# Out:
# Help on built-in function abs in module builtins:
#
# abs(x, /)
#     Return the absolute value of the argument.

# %%
abs(-10)      #Retorno o valor sem sinal, como valor
# Out:
# 10

# %%
help(round)
# Out:
# Help on built-in function round in module builtins:
#
# round(number, ndigits=None)
#     Round a number to a given precision in decimal digits.
#
#     The return value is an integer if ndigits is omitted or None.  Otherwise
#     the return value has the same type as the number.  ndigits may be negative.

# %%
round(1.455678, 2)   #Arredonda para 2 casas decimais
# Out:
# 1.46

# %%
help(pow)
# Out:
# Help on built-in function pow in module builtins:
#
# pow(base, exp, mod=None)
#     Equivalent to base**exp with 2 arguments or base**exp % mod with 3 arguments
#
#     Some types, such as ints, are able to use a more efficient algorithm when
#     invoked using the three argument form.

# %%
pow(2.0, 3) #Potenciação - 2 elevado a 3
# Out:
# 8.0

# %%
int(1.5) #Torna valor decimal em inteiro
# Out:
# 1

# %%
float(1) #torna inteiro em float
# Out:
# 1.0

# %%
str(salario)
# Out:
# '1500'

# %%
help(input)
# Out:
# Help on method raw_input in module ipykernel.kernelbase:
#
# raw_input(prompt='') method of ipykernel.ipkernel.IPythonKernel instance
#     Forward raw_input to frontends
#
#     Raises
#     ------
#     StdinNotImplementedError if active frontend doesn't support stdin.

# %%
nome = input("Digite seu nome: ")
nome
# Out:
# Digite seu nome:  D0uglas
# 'D0uglas'

# %%
altura_centimetros = input("Digite sua altura em centimetros")
altura_centimetros
# Out:
# Digite sua altura em centimetros 175
# '175'

# %%
altura_centimetros = int(altura_centimetros)

# %%
altura_metro = altura_centimetros / 100
altura_metro
# Out:
# 1.75
