# %% [markdown]
# # Tipos de variáveis

# %%
salario_base = 1500
comissao = 0.05
salario_minimo = 1621
nome = "Douglas"
vendas = 500

# %%
type(salario_base)
# Out:
# int

# %%
type(comissao)
# Out:
# float

# %%
type(nome)
# Out:
# str

# %%
salario_final = salario_base + (vendas * comissao)
salario_final
# Out:
# 1525.0

# %%
type(salario_final)
# Out:
# float

# %%
comparacao_com_minimo = salario_base > salario_minimo
comparacao_com_minimo
# Out:
# False

# %%
type(comparacao_com_minimo)
# Out:
# bool
