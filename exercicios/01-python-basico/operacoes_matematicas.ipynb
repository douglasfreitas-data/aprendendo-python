# %% [markdown]
# # Operações Matematicas - parte 1

# %% [markdown]
# ### Principais operações

# %% [markdown]
# Soma

# %%
2 + 5
# Out:
# 7

# %% [markdown]
# Multiplicação

# %%
3 * 9
# Out:
# 27

# %% [markdown]
# Subtração

# %%
4 - 3
# Out:
# 1

# %% [markdown]
# Potenciação

# %%
2**3
# Out:
# 8

# %% [markdown]
# Divisão

# %%
6 / 3 # resultado será float mesmo que os numeros sejam int
# Out:
# 2.0

# %%
5 / 2
# Out:
# 2.5

# %%
5 // 2 # resultado será int
# Out:
# 2

# %% [markdown]
# ### Ordem das operações

# %%
2 + 2 * 3 #Seguem as ordens * / + -
# Out:
# 8

# %%
(2 + 2) * 3 #incia dentro de parenteses
# Out:
# 12

# %% [markdown]
# ### Representando potências de 10

# %%
1.5 * 10**2
# Out:
# 150.0

# %%
1.5 * 10**10
# Out:
# 15000000000.0

# %%
1.5 * 10**20
# Out:
# 1.5e+20

# %% [markdown]
# ### Facilitando a leitura de números grandes

# %%
1_000_000 #separação com "_" de 3 em 3 para melhor visualização do código
# Out:
# 1000000

# %% [markdown]
# ### Cuidados com float

# %%
0.2 + 0.2
# Out:
# 0.4

# %%
0.1 + 0.2 #Esperava 0.3 - conversão do sistema binario para decimal
# Out:
# 0.30000000000000004

# %% [markdown]
# Uma possivel solução é trabalhar com inteiros e depois converte em float:

# %%
10 + 20
# Out:
# 30

# %%
30 / 100
# Out:
# 0.3
