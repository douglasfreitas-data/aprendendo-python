# %% [markdown]
# ## Variáveis

# %%
salario_base = 2500

# %%
descontos = 230

# %%
salario_base, descontos
# Out:
# (2500, 230)

# %%
salario_liquido = salario_base - descontos
print(salario_liquido)
# Out:
# 2270

# %%
salario_liquido = salario_liquido + 200
salario_base
# Out:
# 2500

# %%
salario_liquido += 200
salario_liquido
# Out:
# 3070

# %%
salario_liquido *= 1.5
salario_liquido
# Out:
# 4605.0

# %% [markdown]
# ## Como nomear variáveis
#
# - Não pode começar com números
# - Não pode conter espaços
# - Não porde conter símbolos
# - Evite acentos
# - Pode conter underscore
# - Pode conter letras maiúsculas e minúsculas (case senitive)
#     - No entanto, não é recomendado usar letras maiúsculas no início do nome da variável
#     - Todas as letras maiúsculas é usado para indicar constantes
# - Não pode ser uma palavra reservada
# - Deve ser um nome significativo
# - Evite nomes longos
