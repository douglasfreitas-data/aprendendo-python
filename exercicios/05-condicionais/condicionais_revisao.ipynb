# %% [markdown]
# # Condicionais em Python

# %% [markdown]
# ## Revisão final

# %% [markdown]
# Condicionais:
#
# - controlam o fluxo do código
#
# Sintaxe:
#
# ```python
# if <expressão lógica>:
#     <instrução>
# elif <outra expressão lógica>:
#     <outra instrução>
# ...
# else:
#     <instrução final>
# ```
#
# Resumo visual:

# %% [markdown]
# ![blocos.png](attachment:50564ec2-49a2-4832-a7a1-e463b8eba3fc.png)
